# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('house_data.csv')

# %%
df=pd.read_csv('house_data.csv')
df=pd.read_excel('house_data.xlsx')
#data={'price':[221900,180000,510000],'floors':[1.0,2.0,1.5],'bedrooms':[2,3,1]}
#df=pd.DataFrame(data)

# %%
df.shape
# Out:
# (99, 8)

# %%
rows,columns=df.shape

# %%
rows
# Out:
# 99

# %%
columns
# Out:
# 8

# %%
df.describe()
# Out:
#                  id         price   bedrooms  bathrooms  sqft_living  \
# count  9.900000e+01  9.900000e+01  99.000000  99.000000    99.000000
# mean   4.664620e+09  5.200763e+05   3.404040   1.989899  2086.383838
# std    2.935212e+09  3.061939e+05   0.794358   0.729236   864.592421
# min    1.600040e+07  1.530000e+05   2.000000   1.000000   770.000000
# 25%    1.914950e+09  3.070000e+05   3.000000   1.500000  1410.000000
# 50%    4.036801e+09  4.300000e+05   3.000000   2.000000  1900.000000
# 75%    7.337325e+09  6.562500e+05   4.000000   2.500000  2570.000000
# max    9.822700e+09  2.000000e+06   5.000000   4.500000  5420.000000
#
#             sqft_lot     floors
# count      99.000000  99.000000
# mean    11478.818182   1.464646
# std     14655.249813   0.511363
# min      1044.000000   1.000000
# 25%      5000.000000   1.000000
# 50%      6720.000000   1.500000
# 75%      9823.000000   2.000000
# max    101930.000000   3.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           99 non-null     int64
#  1   date         99 non-null     object
#  2   price        99 non-null     int64
#  3   bedrooms     99 non-null     int64
#  4   bathrooms    99 non-null     float64
#  5   sqft_living  99 non-null     int64
#  6   sqft_lot     99 non-null     int64
#  7   floors       99 non-null     float64
# dtypes: float64(2), int64(5), object(1)
# memory usage: 6.3+ KB

# %%
df.head()
# Out:
#            id             date   price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900         3       1.00         1180
# 1  6414100192  20141209T000000  538000         3       2.25         2570
# 2  5631500400  20150225T000000  180000         2       1.00          770
# 3  2487200875  20141209T000000  604000         4       3.00         1960
# 4  1954400510  20150218T000000  510000         3       2.00         1680
#
#    sqft_lot  floors
# 0      5650     1.0
# 1      7242     2.0
# 2     10000     1.0
# 3      5000     1.0
# 4      8080     1.0

# %%
df.head(7)
# Out:
#            id             date    price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000   221900         3       1.00         1180
# 1  6414100192  20141209T000000   538000         3       2.25         2570
# 2  5631500400  20150225T000000   180000         2       1.00          770
# 3  2487200875  20141209T000000   604000         4       3.00         1960
# 4  1954400510  20150218T000000   510000         3       2.00         1680
# 5  7237550310  20140512T000000  1230000         4       4.50         5420
# 6  1321400060  20140627T000000   257500         3       2.25         1715
#
#    sqft_lot  floors
# 0      5650     1.0
# 1      7242     2.0
# 2     10000     1.0
# 3      5000     1.0
# 4      8080     1.0
# 5    101930     1.0
# 6      6819     2.0

# %%
df.tail()
# Out:
#             id             date   price  bedrooms  bathrooms  sqft_living  \
# 94  6021501535  20141223T000000  700000         3       1.50         1580
# 95  1483300570  20140908T000000  905000         4       2.50         3300
# 96  3422049190  20150330T000000  247500         3       1.75         1960
# 97  1099611230  20140912T000000  199000         4       1.50         1160
# 98   722079104  20140711T000000  314000         3       1.75         1810
#
#     sqft_lot  floors
# 94      5000     1.0
# 95     10250     1.0
# 96     15681     1.0
# 97      6400     1.0
# 98     41800     1.0

# %%
df.tail(3)
# Out:
#             id             date   price  bedrooms  bathrooms  sqft_living  \
# 96  3422049190  20150330T000000  247500         3       1.75         1960
# 97  1099611230  20140912T000000  199000         4       1.50         1160
# 98   722079104  20140711T000000  314000         3       1.75         1810
#
#     sqft_lot  floors
# 96     15681     1.0
# 97      6400     1.0
# 98     41800     1.0

# %%
pd.set_option('display.max_rows',99)
df
# Out:
#             id             date    price  bedrooms  bathrooms  sqft_living  \
# 0   7129300520  20141013T000000   221900         3       1.00         1180
# 1   6414100192  20141209T000000   538000         3       2.25         2570
# 2   5631500400  20150225T000000   180000         2       1.00          770
# 3   2487200875  20141209T000000   604000         4       3.00         1960
# 4   1954400510  20150218T000000   510000         3       2.00         1680
# 5   7237550310  20140512T000000  1230000         4       4.50         5420
# 6   1321400060  20140627T000000   257500         3       2.25         1715
# 7   2008000270  20150115T000000   291850         3       1.50         1060
# 8   2414600126  20150415T000000   229500         3       1.00         1780
# 9   3793500160  20150312T000000   323000         3       2.50         1890
# 10  1736800520  20150403T000000   662500         3       2.50         3560
# ...

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors'],
#       dtype='object')

# %%
df.bedrooms
# Out:
# 0     3
# 1     3
# 2     2
# 3     4
# 4     3
# 5     4
# 6     3
# 7     3
# 8     3
# 9     3
# 10    3
# 11    2
# 12    3
# 13    3
# 14    5
# 15    4
# 16    3
# 17    4
# 18    2
# 19    3
# 20    4
# 21    3
# 22    5
# 23    2
# 24    3
# 25    3
# 26    3
# 27    3
# 28    3
# 29    4
# 30    3
# 31    2
# 32    4
# 33    3
# 34    4
# 35    3
# 36    4
# 37    4
# 38    4
# 39    4
# 40    4
# 41    4
# 42    5
# 43    3
# 44    3
# 45    3
# 46    3
# 47    4
# 48    3
# 49    3
# 50    3
# 51    5
# 52    3
# 53    2
# 54    5
# 55    4
# 56    4
# 57    3
# 58    5
# 59    4
# 60    3
# 61    3
# 62    3
# 63    3
# 64    3
# 65    3
# 66    4
# 67    4
# 68    3
# 69    5
# 70    5
# 71    3
# 72    4
# 73    4
# 74    3
# 75    4
# 76    4
# 77    3
# 78    3
# 79    4
# 80    3
# 81    4
# 82    2
# 83    3
# 84    3
# 85    3
# 86    5
# 87    3
# 88    2
# 89    2
# 90    4
# 91    5
# 92    3
# 93    3
# 94    3
# 95    4
# 96    3
# 97    4
# 98    3
# ...

# %%
df[['date','price','bedrooms']]
# Out:
#                date    price  bedrooms
# 0   20141013T000000   221900         3
# 1   20141209T000000   538000         3
# 2   20150225T000000   180000         2
# 3   20141209T000000   604000         4
# 4   20150218T000000   510000         3
# 5   20140512T000000  1230000         4
# 6   20140627T000000   257500         3
# 7   20150115T000000   291850         3
# 8   20150415T000000   229500         3
# 9   20150312T000000   323000         3
# 10  20150403T000000   662500         3
# 11  20140527T000000   468000         2
# 12  20140528T000000   310000         3
# 13  20141007T000000   400000         3
# 14  20150312T000000   530000         5
# 15  20150124T000000   650000         4
# 16  20140731T000000   395000         3
# 17  20140529T000000   485000         4
# 18  20141205T000000   189000         2
# 19  20150424T000000   230000         3
# 20  20140514T000000   385000         4
# 21  20140826T000000  2000000         3
# 22  20140703T000000   285000         5
# ...

# %%
df.price.max()
# Out:
# 2000000

# %%
df.sqft_living.mean()
# Out:
# 2086.3838383838383

# %%
df['id'].replace(to_replace = np.nan, value = 0, inplace = True)

# %%
df.isnull().sum()
# Out:
# id             0
# date           0
# price          0
# bedrooms       0
# bathrooms      0
# sqft_living    0
# sqft_lot       0
# floors         0
# dtype: int64

# %%
df.fillna(0,inplace=True)

# %%
df.bathrooms.sum()
# Out:
# 197.0

# %%
df.floors.count()
# Out:
# 99

# %%
df.price.unique()
# Out:
# array([ 221900,  538000,  180000,  604000,  510000, 1230000,  257500,
#         291850,  229500,  323000,  662500,  468000,  310000,  400000,
#         530000,  650000,  395000,  485000,  189000,  230000,  385000,
#        2000000,  285000,  252700,  329000,  233000,  937000,  667000,
#         438000,  719000,  580500,  280000,  687500,  535000,  322500,
#         696000,  550000,  640000,  240000,  605000,  625000,  775000,
#         861990,  685000,  309000,  488000,  210490,  785000,  450000,
#        1350000,  228000,  345000,  600000,  585000,  920000,  885000,
#         292500,  301000,  951000,  430000,  289000,  505000,  549000,
#         425000,  317625,  975000,  287000,  204000, 1330000, 1040000,
#         325000,  571000,  360000,  349000,  832500,  380000,  480000,
#         410000,  720000,  390000,  355000,  356000,  315000,  940000,
#         305000,  461000,  215000,  335000,  243500, 1100000,  153000,
# ...

# %%
df.price.value_counts()
# Out:
# 430000     2
# 360000     2
# 650000     2
# 550000     1
# 233000     1
# 180000     1
# 461000     1
# 1040000    1
# 468000     1
# 861990     1
# 329000     1
# 309000     1
# 301000     1
# 700000     1
# 153000     1
# 510000     1
# 285000     1
# 425000     1
# 720000     1
# 315000     1
# 243500     1
# 1100000    1
# 323000     1
# 600000     1
# 1350000    1
# 252700     1
# 1330000    1
# 687500     1
# 640000     1
# 775000     1
# 199000     1
# 247500     1
# 292500     1
# 485000     1
# 488000     1
# 291850     1
# 450000     1
# 585000     1
# 204000     1
# 951000     1
# 538000     1
# 2000000    1
# 215000     1
# 580500     1
# 305000     1
# 571000     1
# 719000     1
# 696000     1
# 685000     1
# 335000     1
# 505000     1
# 310000     1
# 314000     1
# 662500     1
# 355000     1
# 667000     1
# 385000     1
# 885000     1
# 325000     1
# 975000     1
# 937000     1
# 605000     1
# 230000     1
# 832500     1
# 785000     1
# 410000     1
# ...

# %%
df[df.price==df.price.max()]
# Out:
#             id             date    price  bedrooms  bathrooms  sqft_living  \
# 21  2524049179  20140826T000000  2000000         3       2.75         3050
#
#     sqft_lot  floors
# 21     44867     1.0

# %%
df['price'][df['bedrooms']==2]
# Out:
# 2     180000
# 11    468000
# 18    189000
# 23    252700
# 31    280000
# 53    585000
# 82    355000
# 88    215000
# 89    335000
# Name: price, dtype: int64

# %%
df[['price','date']][df['bedrooms']==2]
# Out:
#      price             date
# 2   180000  20150225T000000
# 11  468000  20140527T000000
# 18  189000  20141205T000000
# 23  252700  20140516T000000
# 31  280000  20141201T000000
# 53  585000  20150205T000000
# 82  355000  20141028T000000
# 88  215000  20140519T000000
# 89  335000  20140904T000000

# %%
df.set_index('id',inplace = True)

# %%
df.head()
# Out:
#                        date   price  bedrooms  bathrooms  sqft_living  \
# id
# 7129300520  20141013T000000  221900         3       1.00         1180
# 6414100192  20141209T000000  538000         3       2.25         2570
# 5631500400  20150225T000000  180000         2       1.00          770
# 2487200875  20141209T000000  604000         4       3.00         1960
# 1954400510  20150218T000000  510000         3       2.00         1680
#
#             sqft_lot  floors
# id
# 7129300520      5650     1.0
# 6414100192      7242     2.0
# 5631500400     10000     1.0
# 2487200875      5000     1.0
# 1954400510      8080     1.0

# %%
df.loc[2008000270]
# Out:
# date           20150115T000000
# price                   291850
# bedrooms                     3
# bathrooms                  1.5
# sqft_living               1060
# sqft_lot                  9711
# floors                       1
# Name: 2008000270, dtype: object

# %%
df.reset_index(inplace=True)

# %%
df.head()
# Out:
#            id             date   price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900         3       1.00         1180
# 1  6414100192  20141209T000000  538000         3       2.25         2570
# 2  5631500400  20150225T000000  180000         2       1.00          770
# 3  2487200875  20141209T000000  604000         4       3.00         1960
# 4  1954400510  20150218T000000  510000         3       2.00         1680
#
#    sqft_lot  floors
# 0      5650     1.0
# 1      7242     2.0
# 2     10000     1.0
# 3      5000     1.0
# 4      8080     1.0

# %%
df.set_index('date',inplace= True)

# %%
df.loc['20150205T000000']
# Out:
# id             3.626039e+09
# price          5.850000e+05
# bedrooms       2.000000e+00
# bathrooms      1.750000e+00
# sqft_living    1.980000e+03
# sqft_lot       8.550000e+03
# floors         1.000000e+00
# Name: 20150205T000000, dtype: float64

# %%
df.head()
# Out:
#                          id   price  bedrooms  bathrooms  sqft_living  \
# date
# 20141013T000000  7129300520  221900         3       1.00         1180
# 20141209T000000  6414100192  538000         3       2.25         2570
# 20150225T000000  5631500400  180000         2       1.00          770
# 20141209T000000  2487200875  604000         4       3.00         1960
# 20150218T000000  1954400510  510000         3       2.00         1680
#
#                  sqft_lot  floors
# date
# 20141013T000000      5650     1.0
# 20141209T000000      7242     2.0
# 20150225T000000     10000     1.0
# 20141209T000000      5000     1.0
# 20150218T000000      8080     1.0

# %%
df.rename(columns={'price':'cost'},inplace =True)

# %%
df.head()
# Out:
#                          id    cost  bedrooms  bathrooms  sqft_living  \
# date
# 20141013T000000  7129300520  221900         3       1.00         1180
# 20141209T000000  6414100192  538000         3       2.25         2570
# 20150225T000000  5631500400  180000         2       1.00          770
# 20141209T000000  2487200875  604000         4       3.00         1960
# 20150218T000000  1954400510  510000         3       2.00         1680
#
#                  sqft_lot  floors
# date
# 20141013T000000      5650     1.0
# 20141209T000000      7242     2.0
# 20150225T000000     10000     1.0
# 20141209T000000      5000     1.0
# 20150218T000000      8080     1.0

# %%
dummies=pd.get_dummies(df.floors)

# %%
df=pd.concat([df,dummies],axis='columns')

# %%
df.head()
# Out:
#                          id    cost  bedrooms  bathrooms  sqft_living  \
# date
# 20141013T000000  7129300520  221900         3       1.00         1180
# 20141209T000000  6414100192  538000         3       2.25         2570
# 20150225T000000  5631500400  180000         2       1.00          770
# 20141209T000000  2487200875  604000         4       3.00         1960
# 20150218T000000  1954400510  510000         3       2.00         1680
#
#                  sqft_lot  floors  1.0  1.5  2.0  3.0
# date
# 20141013T000000      5650     1.0    1    0    0    0
# 20141209T000000      7242     2.0    0    0    1    0
# 20150225T000000     10000     1.0    1    0    0    0
# 20141209T000000      5000     1.0    1    0    0    0
# 20150218T000000      8080     1.0    1    0    0    0

# %%
df=df.drop([1.0,1.5,2.0,3.0],axis='columns')

# %%
df.head()
# Out:
#                          id    cost  bedrooms  bathrooms  sqft_living  \
# date
# 20141013T000000  7129300520  221900         3       1.00         1180
# 20141209T000000  6414100192  538000         3       2.25         2570
# 20150225T000000  5631500400  180000         2       1.00          770
# 20141209T000000  2487200875  604000         4       3.00         1960
# 20150218T000000  1954400510  510000         3       2.00         1680
#
#                  sqft_lot  floors
# date
# 20141013T000000      5650     1.0
# 20141209T000000      7242     2.0
# 20150225T000000     10000     1.0
# 20141209T000000      5000     1.0
# 20150218T000000      8080     1.0

# %%
copy=df.copy()

# %%
train=copy.sample(frac=0.75,random_state=1)

# %%
test=copy.drop(train.index)

# %%
train
# Out:
#                          id     cost  bedrooms  bathrooms  sqft_living  \
# date
# 20150226T000000  4168000060   153000         3       1.00         1200
# 20150128T000000  1523059105   356000         3       1.50         1680
# 20140624T000000   461000390   687500         4       1.75         2330
# 20141202T000000  5104520400   390000         3       2.50         2350
# 20140609T000000  6300000287   410000         3       1.00         1410
# 20140529T000000  6865200140   485000         4       1.00         1600
# 20140613T000000  9547205180   696000         3       2.50         2300
# 20141222T000000  7437100340   360000         4       2.50         1900
# 20140519T000000  1332700270   215000         2       2.25         1610
# 20150311T000000  5036300431  1100000         5       2.75         3520
# 20140718T000000  8035350320   488000         3       2.50         3160
# 20141110T000000  7589200193   535000         3       1.00         1090
# ...

# %%
test.count()
# Out:
# id             19
# cost           19
# bedrooms       19
# bathrooms      19
# sqft_living    19
# sqft_lot       19
# floors         19
# dtype: int64
